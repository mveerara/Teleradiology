# %% [markdown]
# <a href="https://colab.research.google.com/github/mveerara/Teleradiology/blob/main/Result_visulaization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import pandas as pd
import os
import numpy

# %%
from google.colab import drive

# %%
drive.mount('/MyDrive')
# Out:
# Mounted at /MyDrive

# %%
img_folder_path='/MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/images/images/00001335_000.png'
frame=cv2.imread(img_folder_path)
print( frame)
# Out:
# [[[251 251 251]
#   [251 251 251]
#   [156 156 156]
#   ...
#   [ 11  11  11]
#   [ 12  12  12]
#   [ 13  13  13]]
#
#  [[252 252 252]
#   [212 212 212]
#   [ 73  73  73]
#   ...
#   [ 12  12  12]
#   [ 13  13  13]
#   [ 15  15  15]]
#
#  [[230 230 230]
#   [ 89  89  89]
#   [ 15  15  15]
#   ...
#   [ 12  12  12]
#   [ 14  14  14]
#   [ 15  15  15]]
#
#  ...
#
#  [[238 238 238]
#   [222 222 222]
#   [223 223 223]
#   ...
#   [212 212 212]
#   [216 216 216]
#   [221 221 221]]
#
#  [[245 245 245]
#   [226 226 226]
#   [226 226 226]
#   ...
#   [212 212 212]
#   [217 217 217]
#   [220 220 220]]
#
#  [[251 251 251]
#   [235 235 235]
#   [229 229 229]
#   ...
#   [212 212 212]
#   [217 217 217]
#   [220 220 220]]]

# %%
pd_bbox = '/MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/output/bounding_box.txt'
ac_bbox = '/MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/BBox_List_2017.txt'

# %%
print(ac_bbox)
# Out:
# /MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/BBox_List_2017.txt

# %%
def plot_bbox(img_folder_path, bbox_filename):
    actual_bbox=open(bbox_filename)
    print(actual_bbox)
    img_folder_path=os.path.split(img_folder_path)[-1]
    print(img_folder_path)
    count=0
    temp_count=0
    final_bbox_list=[]
    for img in actual_bbox :
        print(img)
        if img.find(img_folder_path) != -1:
            print('file exist:',count)
            print('given image',img)
            temp_count=count
            print("this is temp count",temp_count)
        if count > temp_count:

            if img.find('/') == -1 :
                final_bbox_list.append(img)
            else:
                break
        count+=1

    i=final_bbox_list[1]
    temp_i=list(i.split(" "))
    print(temp_i)
    temp_i.pop(0)
    print(temp_i)

    p = numpy.array(temp_i)
    print(p)
    k=p.astype(float)

    x1=int(k[0])
    y1=int(k[1])
    x2=int(k[2])
    y2=int(k[3])
    return x1,y1,x2,y2

# %%
from google.colab.patches import cv2_imshow
print(ac_bbox)
x1,y1,x2,y2=plot_bbox(img_folder_path, ac_bbox)
print(x1,y1,x2,y2)
# Out:
# /MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/BBox_List_2017.txt
# <_io.TextIOWrapper name='/MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/BBox_List_2017.txt' mode='r' encoding='UTF-8'>
# 00000832_005.png
# ['00014716_007.png\tAtelectasis\t686.1016949\t131.5434984\t185.4915254\t313.4915254\n']
# []
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-32167c74e379> in <module>()
#       1 from google.colab.patches import cv2_imshow
#       2 print(ac_bbox)
# ----> 3 x1,y1,x2,y2=plot_bbox(img_folder_path, ac_bbox)
#       4 print(x1,y1,x2,y2)
#       5
#
# <ipython-input-7-472485802857> in plot_bbox(img_folder_path, bbox_filename)
#      31     k=p.astype(float)
#      32
# ---> 33     x1=int(k[0])
#      34     y1=int(k[1])
#      35     x2=int(k[2])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
x_1,y_1,x_2,y_2=plot_bbox(img_folder_path, pd_bbox)
print(pd_bbox)
#print(x_1,y_1,x_2,y_2)

#cv2.rectangle(frame,(x1,y1),(x2,y2),(0,255,0),3) #rgb 220,20,60
cv2.rectangle(frame,(x_1,y_1),(x_2,y_2),(60,20,220),3)
print(frame)

cv2_imshow(frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <_io.TextIOWrapper name='/MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/output/bounding_box.txt' mode='r' encoding='UTF-8'>
# 00000832_005.png
# ['Nodule', '502.4', '458.7', '71.9', '70.4\n']
# ['502.4', '458.7', '71.9', '70.4\n']
# ['502.4' '458.7' '71.9' '70.4\n']
# /MyDrive/MyDrive/Teleradiology/Example_Program/example1/Dataset/output/bounding_box.txt
# [[[ 29  29  29]
#   [ 22  22  22]
#   [ 21  21  21]
#   ...
#   [ 29  29  29]
#   [ 31  31  31]
#   [ 33  33  33]]
#
#  [[ 28  28  28]
#   [ 26  26  26]
#   [ 25  25  25]
#   ...
#   [ 30  30  30]
#   [ 32  32  32]
#   [ 34  34  34]]
#
#  [[ 25  25  25]
#   [ 26  26  26]
#   [ 26  26  26]
#   ...
#   [ 29  29  29]
#   [ 32  32  32]
#   [ 34  34  34]]
#
#  ...
#
#  [[ 26  26  26]
#   [ 27  27  27]
#   [ 26  26  26]
#   ...
#   [203 203 203]
#   [204 204 204]
#   [205 205 205]]
#
#  [[ 28  28  28]
#   [ 28  28  28]
#   [ 30  30  30]
#   ...
#   [203 203 203]
#   [205 205 205]
#   [206 206 206]]
#
#  [[ 29  29  29]
#   [ 29  29  29]
#   [ 30  30  30]
#   ...
#   [203 203 203]
#   [205 205 205]
#   [206 206 206]]]
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7F5A55392490>
